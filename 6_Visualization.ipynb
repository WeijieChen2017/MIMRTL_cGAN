# %%
import os
import glob
import cv2
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt

# %%
def maxmin_norm(data):
    MAX = np.amax(data)
    MIN = np.amin(data)
    data = (data - MIN)/(MAX-MIN)
    return data

# %%
def norm_cut(data, cut_min, cut_max, run=False):
    if run:
        data[data<cut_min] = cut_min
        data[data>cut_max] = cut_max
    return maxmin_norm(data)*255

# %%
folder_name = "pure_unet"
cut_min = 4300
cut_max = 7700
display_zoom = 8

# %%
path = "./results/"+folder_name+"/vis/"
if not os.path.exists(path):
    os.makedirs(path)

# %%
list_nii = glob.glob("./results/"+folder_name+"/*.nii")
list_nii.sort()
list_data = []
list_name = []
for path_nii in list_nii:
    print(path_nii)
    name_nii = os.path.basename(path_nii)
    data = nib.load(path_nii).get_fdata()
    run_bool = 'pet' in name_nii
    print("Norm cut:",run_bool)
    list_data.append(norm_cut(data, cut_min=cut_min, cut_max=cut_max, run=run_bool))
    list_name.append(name_nii)
# Out:
# ./results/pure_unet/subj01_pet_pure_unet_fake.nii
# Norm cut: True
# ./results/pure_unet/subj01_pet_pure_unet_real.nii
# Norm cut: True
# ./results/pure_unet/subj01_t1bravo.nii
# Norm cut: False

# %%
layout_hub = [[0,0],[1,1],[1,2],[1,3],[1,4]]
layout = layout_hub[len(list_nii)]
print(layout)
# Out:
# [1, 3]

# %%
for idx_v in range(list_data[0].shape[2]):
    plt.figure(figsize=(layout[1]*display_zoom, layout[0]*display_zoom), dpi=144)
    # fig, axes = plt.subplots(nrows=layout[0], ncols=layout[1])
    for idx in range(len(list_nii)):
        plt.subplot(layout[0], layout[1], idx+1)
        plt.imshow(np.rot90(list_data[idx][:, :, idx_v]), cmap='gray')
        plt.axis("off")
        plt.title(list_name[idx])
    savename = path+folder_name+"_"+str(idx_v)+".jpg"
    # fig.tight_layout()
    plt.savefig(savename)
    plt.close()
    print(savename)
# Out:
# ./results/pure_unet/vis/pure_unet_0.jpg
# ./results/pure_unet/vis/pure_unet_1.jpg
# ./results/pure_unet/vis/pure_unet_2.jpg
# ./results/pure_unet/vis/pure_unet_3.jpg
# ./results/pure_unet/vis/pure_unet_4.jpg
# ./results/pure_unet/vis/pure_unet_5.jpg
# ./results/pure_unet/vis/pure_unet_6.jpg
# ./results/pure_unet/vis/pure_unet_7.jpg
# ./results/pure_unet/vis/pure_unet_8.jpg
# ./results/pure_unet/vis/pure_unet_9.jpg
# ./results/pure_unet/vis/pure_unet_10.jpg
# ./results/pure_unet/vis/pure_unet_11.jpg
# ./results/pure_unet/vis/pure_unet_12.jpg
# ./results/pure_unet/vis/pure_unet_13.jpg
# ./results/pure_unet/vis/pure_unet_14.jpg
# ./results/pure_unet/vis/pure_unet_15.jpg
# ./results/pure_unet/vis/pure_unet_16.jpg
# ./results/pure_unet/vis/pure_unet_17.jpg
# ./results/pure_unet/vis/pure_unet_18.jpg
# ./results/pure_unet/vis/pure_unet_19.jpg
# ./results/pure_unet/vis/pure_unet_20.jpg
# ./results/pure_unet/vis/pure_unet_21.jpg
# ./results/pure_unet/vis/pure_unet_22.jpg
# ./results/pure_unet/vis/pure_unet_23.jpg
# ./results/pure_unet/vis/pure_unet_24.jpg
# ./results/pure_unet/vis/pure_unet_25.jpg
# ./results/pure_unet/vis/pure_unet_26.jpg
# ./results/pure_unet/vis/pure_unet_27.jpg
# ./results/pure_unet/vis/pure_unet_28.jpg
# ./results/pure_unet/vis/pure_unet_29.jpg
# ./results/pure_unet/vis/pure_unet_30.jpg
# ./results/pure_unet/vis/pure_unet_31.jpg
# ./results/pure_unet/vis/pure_unet_32.jpg
# ./results/pure_unet/vis/pure_unet_33.jpg
# ./results/pure_unet/vis/pure_unet_34.jpg
# ./results/pure_unet/vis/pure_unet_35.jpg
# ./results/pure_unet/vis/pure_unet_36.jpg
# ./results/pure_unet/vis/pure_unet_37.jpg
# ./results/pure_unet/vis/pure_unet_38.jpg
# ./results/pure_unet/vis/pure_unet_39.jpg
# ./results/pure_unet/vis/pure_unet_40.jpg
# ./results/pure_unet/vis/pure_unet_41.jpg
# ./results/pure_unet/vis/pure_unet_42.jpg
# ./results/pure_unet/vis/pure_unet_43.jpg
# ./results/pure_unet/vis/pure_unet_44.jpg
# ./results/pure_unet/vis/pure_unet_45.jpg
# ./results/pure_unet/vis/pure_unet_46.jpg
# ./results/pure_unet/vis/pure_unet_47.jpg
# ./results/pure_unet/vis/pure_unet_48.jpg
# ./results/pure_unet/vis/pure_unet_49.jpg
# ./results/pure_unet/vis/pure_unet_50.jpg
# ./results/pure_unet/vis/pure_unet_51.jpg
# ./results/pure_unet/vis/pure_unet_52.jpg
# ./results/pure_unet/vis/pure_unet_53.jpg
# ./results/pure_unet/vis/pure_unet_54.jpg
# ./results/pure_unet/vis/pure_unet_55.jpg
# ./results/pure_unet/vis/pure_unet_56.jpg
# ./results/pure_unet/vis/pure_unet_57.jpg
# ./results/pure_unet/vis/pure_unet_58.jpg
# ./results/pure_unet/vis/pure_unet_59.jpg
# ./results/pure_unet/vis/pure_unet_60.jpg
# ./results/pure_unet/vis/pure_unet_61.jpg
# ./results/pure_unet/vis/pure_unet_62.jpg
# ./results/pure_unet/vis/pure_unet_63.jpg
# ./results/pure_unet/vis/pure_unet_64.jpg
# ./results/pure_unet/vis/pure_unet_65.jpg
# ./results/pure_unet/vis/pure_unet_66.jpg
# ./results/pure_unet/vis/pure_unet_67.jpg
# ./results/pure_unet/vis/pure_unet_68.jpg
# ./results/pure_unet/vis/pure_unet_69.jpg
# ./results/pure_unet/vis/pure_unet_70.jpg
# ./results/pure_unet/vis/pure_unet_71.jpg
# ./results/pure_unet/vis/pure_unet_72.jpg
# ./results/pure_unet/vis/pure_unet_73.jpg
# ./results/pure_unet/vis/pure_unet_74.jpg
# ./results/pure_unet/vis/pure_unet_75.jpg
# ./results/pure_unet/vis/pure_unet_76.jpg
# ./results/pure_unet/vis/pure_unet_77.jpg
# ./results/pure_unet/vis/pure_unet_78.jpg
# ./results/pure_unet/vis/pure_unet_79.jpg
# ./results/pure_unet/vis/pure_unet_80.jpg
# ./results/pure_unet/vis/pure_unet_81.jpg
# ./results/pure_unet/vis/pure_unet_82.jpg
# ./results/pure_unet/vis/pure_unet_83.jpg
# ./results/pure_unet/vis/pure_unet_84.jpg
# ./results/pure_unet/vis/pure_unet_85.jpg
# ./results/pure_unet/vis/pure_unet_86.jpg
# ./results/pure_unet/vis/pure_unet_87.jpg
# ./results/pure_unet/vis/pure_unet_88.jpg
# ./results/pure_unet/vis/pure_unet_89.jpg
# ./results/pure_unet/vis/pure_unet_90.jpg
# ./results/pure_unet/vis/pure_unet_91.jpg
# ./results/pure_unet/vis/pure_unet_92.jpg
# ./results/pure_unet/vis/pure_unet_93.jpg
# ./results/pure_unet/vis/pure_unet_94.jpg
# ./results/pure_unet/vis/pure_unet_95.jpg
# ./results/pure_unet/vis/pure_unet_96.jpg
# ./results/pure_unet/vis/pure_unet_97.jpg
# ./results/pure_unet/vis/pure_unet_98.jpg
# ./results/pure_unet/vis/pure_unet_99.jpg
# ./results/pure_unet/vis/pure_unet_100.jpg
# ./results/pure_unet/vis/pure_unet_101.jpg
# ./results/pure_unet/vis/pure_unet_102.jpg
# ./results/pure_unet/vis/pure_unet_103.jpg
# ./results/pure_unet/vis/pure_unet_104.jpg
# ./results/pure_unet/vis/pure_unet_105.jpg
# ./results/pure_unet/vis/pure_unet_106.jpg
# ./results/pure_unet/vis/pure_unet_107.jpg
# ./results/pure_unet/vis/pure_unet_108.jpg
# ./results/pure_unet/vis/pure_unet_109.jpg
# ./results/pure_unet/vis/pure_unet_110.jpg
# ./results/pure_unet/vis/pure_unet_111.jpg
# ./results/pure_unet/vis/pure_unet_112.jpg
# ./results/pure_unet/vis/pure_unet_113.jpg
# ./results/pure_unet/vis/pure_unet_114.jpg
# ./results/pure_unet/vis/pure_unet_115.jpg
# ./results/pure_unet/vis/pure_unet_116.jpg
# ./results/pure_unet/vis/pure_unet_117.jpg
# ./results/pure_unet/vis/pure_unet_118.jpg
# ./results/pure_unet/vis/pure_unet_119.jpg
# ./results/pure_unet/vis/pure_unet_120.jpg
# ./results/pure_unet/vis/pure_unet_121.jpg
# ./results/pure_unet/vis/pure_unet_122.jpg
# ./results/pure_unet/vis/pure_unet_123.jpg
# ./results/pure_unet/vis/pure_unet_124.jpg
# ./results/pure_unet/vis/pure_unet_125.jpg
# ./results/pure_unet/vis/pure_unet_126.jpg
# ./results/pure_unet/vis/pure_unet_127.jpg
# ./results/pure_unet/vis/pure_unet_128.jpg
# ./results/pure_unet/vis/pure_unet_129.jpg
# ./results/pure_unet/vis/pure_unet_130.jpg
# ./results/pure_unet/vis/pure_unet_131.jpg
# ./results/pure_unet/vis/pure_unet_132.jpg
# ./results/pure_unet/vis/pure_unet_133.jpg
# ./results/pure_unet/vis/pure_unet_134.jpg
# ./results/pure_unet/vis/pure_unet_135.jpg
# ./results/pure_unet/vis/pure_unet_136.jpg
# ./results/pure_unet/vis/pure_unet_137.jpg
# ./results/pure_unet/vis/pure_unet_138.jpg
# ./results/pure_unet/vis/pure_unet_139.jpg
# ./results/pure_unet/vis/pure_unet_140.jpg
# ./results/pure_unet/vis/pure_unet_141.jpg
# ./results/pure_unet/vis/pure_unet_142.jpg
# ./results/pure_unet/vis/pure_unet_143.jpg
# ./results/pure_unet/vis/pure_unet_144.jpg
# ./results/pure_unet/vis/pure_unet_145.jpg
# ./results/pure_unet/vis/pure_unet_146.jpg
# ./results/pure_unet/vis/pure_unet_147.jpg
# ./results/pure_unet/vis/pure_unet_148.jpg
# ./results/pure_unet/vis/pure_unet_149.jpg
# ./results/pure_unet/vis/pure_unet_150.jpg
# ./results/pure_unet/vis/pure_unet_151.jpg
# ./results/pure_unet/vis/pure_unet_152.jpg
# ./results/pure_unet/vis/pure_unet_153.jpg
# ./results/pure_unet/vis/pure_unet_154.jpg
# ./results/pure_unet/vis/pure_unet_155.jpg
# ./results/pure_unet/vis/pure_unet_156.jpg
# ./results/pure_unet/vis/pure_unet_157.jpg
# ./results/pure_unet/vis/pure_unet_158.jpg
# ./results/pure_unet/vis/pure_unet_159.jpg
# ./results/pure_unet/vis/pure_unet_160.jpg
# ./results/pure_unet/vis/pure_unet_161.jpg
# ./results/pure_unet/vis/pure_unet_162.jpg
# ./results/pure_unet/vis/pure_unet_163.jpg
# ./results/pure_unet/vis/pure_unet_164.jpg
# ./results/pure_unet/vis/pure_unet_165.jpg
# ./results/pure_unet/vis/pure_unet_166.jpg
# ./results/pure_unet/vis/pure_unet_167.jpg
# ./results/pure_unet/vis/pure_unet_168.jpg
# ./results/pure_unet/vis/pure_unet_169.jpg
# ./results/pure_unet/vis/pure_unet_170.jpg
# ./results/pure_unet/vis/pure_unet_171.jpg
# ./results/pure_unet/vis/pure_unet_172.jpg
# ./results/pure_unet/vis/pure_unet_173.jpg
# ./results/pure_unet/vis/pure_unet_174.jpg
# ./results/pure_unet/vis/pure_unet_175.jpg
# ./results/pure_unet/vis/pure_unet_176.jpg
# ./results/pure_unet/vis/pure_unet_177.jpg
# ./results/pure_unet/vis/pure_unet_178.jpg
# ./results/pure_unet/vis/pure_unet_179.jpg
# ./results/pure_unet/vis/pure_unet_180.jpg
# ./results/pure_unet/vis/pure_unet_181.jpg
# ./results/pure_unet/vis/pure_unet_182.jpg
# ./results/pure_unet/vis/pure_unet_183.jpg
# ./results/pure_unet/vis/pure_unet_184.jpg
# ./results/pure_unet/vis/pure_unet_185.jpg
# ./results/pure_unet/vis/pure_unet_186.jpg
# ./results/pure_unet/vis/pure_unet_187.jpg
# ./results/pure_unet/vis/pure_unet_188.jpg
# ./results/pure_unet/vis/pure_unet_189.jpg
# ./results/pure_unet/vis/pure_unet_190.jpg
# ./results/pure_unet/vis/pure_unet_191.jpg
# ./results/pure_unet/vis/pure_unet_192.jpg
# ./results/pure_unet/vis/pure_unet_193.jpg
# ./results/pure_unet/vis/pure_unet_194.jpg
# ./results/pure_unet/vis/pure_unet_195.jpg
# ./results/pure_unet/vis/pure_unet_196.jpg
# ./results/pure_unet/vis/pure_unet_197.jpg
# ./results/pure_unet/vis/pure_unet_198.jpg
# ./results/pure_unet/vis/pure_unet_199.jpg
# ./results/pure_unet/vis/pure_unet_200.jpg
# ./results/pure_unet/vis/pure_unet_201.jpg
# ./results/pure_unet/vis/pure_unet_202.jpg
# ./results/pure_unet/vis/pure_unet_203.jpg
# ./results/pure_unet/vis/pure_unet_204.jpg
# ./results/pure_unet/vis/pure_unet_205.jpg
# ./results/pure_unet/vis/pure_unet_206.jpg
# ./results/pure_unet/vis/pure_unet_207.jpg
# ./results/pure_unet/vis/pure_unet_208.jpg
# ./results/pure_unet/vis/pure_unet_209.jpg
# ./results/pure_unet/vis/pure_unet_210.jpg
# ./results/pure_unet/vis/pure_unet_211.jpg
# ./results/pure_unet/vis/pure_unet_212.jpg
# ./results/pure_unet/vis/pure_unet_213.jpg
# ./results/pure_unet/vis/pure_unet_214.jpg
# ./results/pure_unet/vis/pure_unet_215.jpg
# ./results/pure_unet/vis/pure_unet_216.jpg
# ./results/pure_unet/vis/pure_unet_217.jpg
# ./results/pure_unet/vis/pure_unet_218.jpg
# ./results/pure_unet/vis/pure_unet_219.jpg
# ./results/pure_unet/vis/pure_unet_220.jpg
# ./results/pure_unet/vis/pure_unet_221.jpg
# ./results/pure_unet/vis/pure_unet_222.jpg
# ./results/pure_unet/vis/pure_unet_223.jpg
# ./results/pure_unet/vis/pure_unet_224.jpg
# ./results/pure_unet/vis/pure_unet_225.jpg
# ./results/pure_unet/vis/pure_unet_226.jpg
# ./results/pure_unet/vis/pure_unet_227.jpg
# ./results/pure_unet/vis/pure_unet_228.jpg
# ./results/pure_unet/vis/pure_unet_229.jpg
# ./results/pure_unet/vis/pure_unet_230.jpg
# ./results/pure_unet/vis/pure_unet_231.jpg
# ./results/pure_unet/vis/pure_unet_232.jpg
# ./results/pure_unet/vis/pure_unet_233.jpg
# ./results/pure_unet/vis/pure_unet_234.jpg
# ./results/pure_unet/vis/pure_unet_235.jpg
# ./results/pure_unet/vis/pure_unet_236.jpg
# ./results/pure_unet/vis/pure_unet_237.jpg
# ./results/pure_unet/vis/pure_unet_238.jpg
# ./results/pure_unet/vis/pure_unet_239.jpg
# ./results/pure_unet/vis/pure_unet_240.jpg
# ./results/pure_unet/vis/pure_unet_241.jpg
# ./results/pure_unet/vis/pure_unet_242.jpg
# ./results/pure_unet/vis/pure_unet_243.jpg
# ./results/pure_unet/vis/pure_unet_244.jpg
# ./results/pure_unet/vis/pure_unet_245.jpg
# ./results/pure_unet/vis/pure_unet_246.jpg
# ./results/pure_unet/vis/pure_unet_247.jpg
# ./results/pure_unet/vis/pure_unet_248.jpg
# ./results/pure_unet/vis/pure_unet_249.jpg
# ./results/pure_unet/vis/pure_unet_250.jpg
# ./results/pure_unet/vis/pure_unet_251.jpg
# ./results/pure_unet/vis/pure_unet_252.jpg
# ./results/pure_unet/vis/pure_unet_253.jpg
# ./results/pure_unet/vis/pure_unet_254.jpg
# ./results/pure_unet/vis/pure_unet_255.jpg
# ./results/pure_unet/vis/pure_unet_256.jpg
# ./results/pure_unet/vis/pure_unet_257.jpg
# ./results/pure_unet/vis/pure_unet_258.jpg
# ./results/pure_unet/vis/pure_unet_259.jpg
# ./results/pure_unet/vis/pure_unet_260.jpg
# ./results/pure_unet/vis/pure_unet_261.jpg
# ./results/pure_unet/vis/pure_unet_262.jpg
# ./results/pure_unet/vis/pure_unet_263.jpg
# ./results/pure_unet/vis/pure_unet_264.jpg
# ./results/pure_unet/vis/pure_unet_265.jpg
# ./results/pure_unet/vis/pure_unet_266.jpg
# ./results/pure_unet/vis/pure_unet_267.jpg
# ./results/pure_unet/vis/pure_unet_268.jpg
# ./results/pure_unet/vis/pure_unet_269.jpg
# ./results/pure_unet/vis/pure_unet_270.jpg
# ./results/pure_unet/vis/pure_unet_271.jpg
# ./results/pure_unet/vis/pure_unet_272.jpg
# ./results/pure_unet/vis/pure_unet_273.jpg
# ./results/pure_unet/vis/pure_unet_274.jpg
# ./results/pure_unet/vis/pure_unet_275.jpg
# ./results/pure_unet/vis/pure_unet_276.jpg
# ./results/pure_unet/vis/pure_unet_277.jpg
# ./results/pure_unet/vis/pure_unet_278.jpg
# ./results/pure_unet/vis/pure_unet_279.jpg
# ./results/pure_unet/vis/pure_unet_280.jpg
# ./results/pure_unet/vis/pure_unet_281.jpg
# ./results/pure_unet/vis/pure_unet_282.jpg
# ./results/pure_unet/vis/pure_unet_283.jpg
